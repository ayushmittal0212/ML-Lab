# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Dataset/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.model_selection import train_test_split


X=data.drop('Outcome',axis=1)
y=data['Outcome']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)
print(X_train,y_train)
print(X_test,y_test)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 603            7      150             78             29      126  35.2
# 118            4       97             60             23        0  28.2
# 247            0      165             90             33      680  52.3
# 157            1      109             56             21      135  25.2
# 468            8      120              0              0        0  30.0
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 192            7      159             66              0        0  30.4
# 629            4       94             65             22        0  24.7
# 559           11       85             74              0        0  30.1
# 684            5      136             82              0        0   0.0
#
#      DiabetesPedigreeFunction  Age
# 603                     0.692   54
# 118                     0.443   22
# 247                     0.427   23
# 157                     0.833   23
# 468                     0.183   38
# ..                        ...  ...
# 763                     0.171   63
# 192                     0.383   36
# 629                     0.148   21
# 559                     0.300   35
# 684                     0.640   69
#
# [614 rows x 8 columns] 603    1
# 118    0
# 247    0
# 157    0
# 468    1
#       ..
# 763    0
# 192    1
# 629    0
# 559    0
# 684    0
# Name: Outcome, Length: 614, dtype: int64
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 661            1      199             76             43        0  42.9
# 122            2      107             74             30      100  33.6
# 113            4       76             62              0        0  34.0
# 14             5      166             72             19      175  25.8
# 529            0      111             65              0        0  24.6
# ..           ...      ...            ...            ...      ...   ...
# 476            2      105             80             45      191  33.7
# 482            4       85             58             22       49  27.8
# 230            4      142             86              0        0  44.0
# 527            3      116             74             15      105  26.3
# 380            1      107             72             30       82  30.8
#
#      DiabetesPedigreeFunction  Age
# 661                     1.394   22
# 122                     0.404   23
# 113                     0.391   25
# 14                      0.587   51
# 529                     0.660   31
# ..                        ...  ...
# 476                     0.711   29
# 482                     0.306   28
# 230                     0.645   22
# 527                     0.107   24
# 380                     0.821   24
#
# [154 rows x 8 columns] 661    1
# 122    0
# 113    0
# 14     1
# 529    0
#       ..
# 476    1
# 482    0
# 230    1
# 527    0
# 380    0
# Name: Outcome, Length: 154, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

DTCg=DecisionTreeClassifier(max_depth=4,criterion='gini')
DTCe=DecisionTreeClassifier(max_depth=4,criterion='entropy')
modele=DTCe.fit(X_train,y_train)
modelg=DTCg.fit(X_train,y_train)
y_predg=modelg.predict(X_test)
y_prede=modele.predict(X_test)

# %%
from sklearn import metrics
print('Accuracy of model using gini: ',metrics.accuracy_score(y_test,y_predg))
print('Accuracy of model using entropy: ',metrics.accuracy_score(y_test,y_prede))
# Out:
# Accuracy of model using gini:  0.7662337662337663
# Accuracy of model using entropy:  0.7402597402597403

# %%
from sklearn import tree
fig = plt.figure(figsize=(25,20))
tree.plot_tree(DTCg,filled=True)
# Out:
# [Text(0.4791666666666667, 0.9, 'x[1] <= 123.5\ngini = 0.461\nsamples = 614\nvalue = [393, 221]'),
#  Text(0.2708333333333333, 0.7, 'x[7] <= 28.5\ngini = 0.301\nsamples = 352\nvalue = [287, 65]'),
#  Text(0.16666666666666666, 0.5, 'x[5] <= 30.95\ngini = 0.162\nsamples = 202\nvalue = [184, 18]'),
#  Text(0.08333333333333333, 0.3, 'x[0] <= 7.0\ngini = 0.036\nsamples = 110\nvalue = [108, 2]'),
#  Text(0.041666666666666664, 0.1, 'gini = 0.018\nsamples = 109\nvalue = [108, 1]'),
#  Text(0.125, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.25, 0.3, 'x[2] <= 53.0\ngini = 0.287\nsamples = 92\nvalue = [76, 16]'),
#  Text(0.20833333333333334, 0.1, 'gini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.2916666666666667, 0.1, 'gini = 0.24\nsamples = 86\nvalue = [74, 12]'),
#  Text(0.375, 0.5, 'x[5] <= 26.35\ngini = 0.43\nsamples = 150\nvalue = [103, 47]'),
#  Text(0.3333333333333333, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.4166666666666667, 0.3, 'x[1] <= 99.5\ngini = 0.475\nsamples = 121\nvalue = [74, 47]'),
#  Text(0.375, 0.1, 'gini = 0.337\nsamples = 42\nvalue = [33, 9]'),
#  Text(0.4583333333333333, 0.1, 'gini = 0.499\nsamples = 79\nvalue = [41, 38]'),
#  Text(0.6875, 0.7, 'x[5] <= 30.05\ngini = 0.482\nsamples = 262\nvalue = [106, 156]'),
#  Text(0.5416666666666666, 0.5, 'x[7] <= 26.0\ngini = 0.438\nsamples = 74\nvalue = [50, 24]'),
#  Text(0.5, 0.3, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.5833333333333334, 0.3, 'x[7] <= 60.5\ngini = 0.492\nsamples = 55\nvalue = [31, 24]'),
#  Text(0.5416666666666666, 0.1, 'gini = 0.5\nsamples = 47\nvalue = [23, 24]'),
#  Text(0.625, 0.1, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.8333333333333334, 0.5, 'x[1] <= 157.5\ngini = 0.418\nsamples = 188\nvalue = [56, 132]'),
#  Text(0.75, 0.3, 'x[7] <= 28.5\ngini = 0.482\nsamples = 116\nvalue = [47, 69]'),
#  Text(0.7083333333333334, 0.1, 'gini = 0.49\nsamples = 42\nvalue = [24, 18]'),
#  Text(0.7916666666666666, 0.1, 'gini = 0.428\nsamples = 74\nvalue = [23, 51]'),
#  Text(0.9166666666666666, 0.3, 'x[4] <= 595.0\ngini = 0.219\nsamples = 72\nvalue = [9, 63]'),
#  Text(0.875, 0.1, 'gini = 0.182\nsamples = 69\nvalue = [7, 62]'),
#  Text(0.9583333333333334, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]')]
